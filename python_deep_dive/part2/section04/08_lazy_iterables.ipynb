# %%
import math

# %%
class Circle:
    def __init__(self, r):
        self._radius = r
    
    @property
    def radius(self):
        return self._radius
    
    @radius.setter
    def radius(self, r):
        self._radius = r
        self.area = math.pi * (r ** 2)

# %%
c = Circle(1)

# %%
c.radius
# Out:
# 1

# %%
c.area
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 c.area
#
# AttributeError: 'Circle' object has no attribute 'area'

# %%
c.radius = 2

# %%
c.area
# Out:
# 12.566370614359172

# %%
class Circle:
    def __init__(self, r):
        self._radius = r
    
    @property
    def radius(self):
        return self._radius
    
    @radius.setter
    def radius(self, r):
        self._radius = r
        
    @property
    def area(self):
        print("Calculate area...")
        return math.pi * (self.radius ** 2)

# %%
c = Circle(1)

# %%
c.area
# Out:
# Calculate area...
# 3.141592653589793

# %%
c.radius = 2

# %%
c.area
# Out:
# Calculate area...
# 12.566370614359172

# %%
c.area
# Out:
# Calculate area...
# 12.566370614359172

# %%
class Circle:
    def __init__(self, r):
        self._radius = r
        self._area = None
    
    @property
    def radius(self):
        return self._radius
    
    @radius.setter
    def radius(self, r):
        self._radius = r
        self._area = None
        
    @property
    def area(self):
        if self._area is None:
            print("Calculate area...")
            self._area = math.pi * (self.radius ** 2)
        return self._area

# %%
c = Circle(1)

# %%
c.area
# Out:
# Calculate area...
# 3.141592653589793

# %%
c.area
# Out:
# 3.141592653589793

# %%
c.radius = 2

# %%
c.area
# Out:
# Calculate area...
# 12.566370614359172

# %%
c.area
# Out:
# 12.566370614359172

# %%
class Factorials:
    def __init__(self, length):
        self.length = length

    def __iter__(self):
        return self.FactIter(self.length)

    class FactIter:
        def __init__(self, length):
            self.length = length
            self.i = 0
        
        def __iter__(self):
            return self
        
        def __next__(self):
            if self.i >= self.length:
                raise StopIteration
            else:
                result = math.factorial(self.i)
                self.i += 1
                return result

# %%
facts = Factorials(5)

# %%
list(facts)
# Out:
# [1, 1, 2, 6, 24]

# %%
class Factorials:
    """Implement with infinitive loop."""
    
    def __iter__(self):
        return self.FactIter()

    class FactIter:
        def __init__(self):
            self.i = 0
        
        def __iter__(self):
            return self
        
        def __next__(self):
            result = math.factorial(self.i)
            self.i += 1
            return result

# %%
facts = Factorials()

# %%
# Not using for loop, by using iterator can using next to get next value
# with infinitive loop.
fact_iter = iter(facts)

# %%
next(fact_iter)
# Out:
# 1

# %%
next(fact_iter)
# Out:
# 1

# %%
next(fact_iter)
# Out:
# 2

# %%
next(fact_iter)
# Out:
# 6

# %%
next(fact_iter)
# Out:
# 24
