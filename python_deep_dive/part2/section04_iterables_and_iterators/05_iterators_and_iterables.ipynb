# %%
class Cities:
    def __init__(self):
        self._cities = ['Paris', 'Berlin', 'Rome', 'Marid', 'London']
        self._index = 0
    
    def __iter__(self):
        return self
    
    def __next__(self):
        if self._index >= len(self._cities):
            raise StopIteration
        else:
            item = self._cities[self._index]
            self._index += 1
            return item

# %%
cities = Cities()

# %%
type(cities)
# Out:
# __main__.Cities

# %%
list(enumerate(cities))
# Out:
# [(0, 'Paris'), (1, 'Berlin'), (2, 'Rome'), (3, 'Marid'), (4, 'London')]

# %%
next(cities)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 next(cities)
#
# Cell In[2], line 11, in Cities.__next__(self)
#       9 def __next__(self):
#      10     if self._index >= len(self._cities):
# ---> 11         raise StopIteration
#      12     else:
#      13         item = self._cities[self._index]
#
# StopIteration:

# %%
list(enumerate(cities))
# Out:
# []

# %%
cities = Cities()
[item.upper() for item in cities]
# Out:
# ['PARIS', 'BERLIN', 'ROME', 'MARID', 'LONDON']

# %%
class Cities:
    def __init__(self):
        self._cities = ['Paris', 'Berlin', 'Rome', 'Marid', 'London']
        self._index = 0

    def __len__(self):
        return len(self._cities)

# %%
cities = Cities()

# %%
len(cities)
# Out:
# 5

# %%
class CityIterator:
    def __init__(self, city_obj: Cities):
        self._city_obj = city_obj
        self._index = 0
    
    def __iter__(self):
        return self
    
    def __next__(self):
        if self._index >= len(self._city_obj):
            raise StopIteration
        else:
            item = self._city_obj._cities[self._index]
            self._index += 1
            return item

# %%
cities = Cities()

# %%
city_iterator = CityIterator(cities)

# %%
for city in city_iterator:
    print(city)
# Out:
# Paris
# Berlin
# Rome
# Marid
# London

# %%
for city in city_iterator:
    print(city)

# %%
city_iterator = CityIterator(cities)

for city in city_iterator:
    print(city)
# Out:
# Paris
# Berlin
# Rome
# Marid
# London

# %%
class Cities:
    def __init__(self):
        self._cities = ['Paris', 'Berlin', 'Rome', 'Marid', 'London']
        self._index = 0

    def __len__(self):
        return len(self._cities)
    
    def __iter__(self):
        return CityIterator(self)

# %%
cities = Cities()

# %%
for city in cities:
    print(city)
# Out:
# Paris
# Berlin
# Rome
# Marid
# London

# %%
class CityIterator:
    def __init__(self, city_obj: Cities):
        print("CityIterator new object")
        self._city_obj = city_obj
        self._index = 0
    
    def __iter__(self):
        print('CityIterator __iter__ called!')
        return self
    
    def __next__(self):
        print("CityIterator __next__ called")
        if self._index >= len(self._city_obj):
            raise StopIteration
        else:
            item = self._city_obj._cities[self._index]
            self._index += 1
            return item
    

class Cities:
    def __init__(self):
        self._cities = ['Paris', 'Berlin', 'Rome', 'Marid', 'London']
        self._index = 0

    def __len__(self):
        return len(self._cities)
    
    def __iter__(self):
        print("Cities __iter__ called")
        return CityIterator(self)

# %%
cities = Cities()

# %%
for city in cities:
    print(city)
# Out:
# Cities __iter__ called
# CityIterator new object
# CityIterator __next__ called
# Paris
# CityIterator __next__ called
# Berlin
# CityIterator __next__ called
# Rome
# CityIterator __next__ called
# Marid
# CityIterator __next__ called
# London
# CityIterator __next__ called

# %%
for city in cities:
    print(city)
# Out:
# Cities __iter__ called
# CityIterator new object
# CityIterator __next__ called
# Paris
# CityIterator __next__ called
# Berlin
# CityIterator __next__ called
# Rome
# CityIterator __next__ called
# Marid
# CityIterator __next__ called
# London
# CityIterator __next__ called

# %%
city_iter_1 = cities.__iter__()
city_iter_2 = cities.__iter__()
# Out:
# Cities __iter__ called
# CityIterator new object
# Cities __iter__ called
# CityIterator new object

# %%
city_iter_1 == city_iter_2
# Out:
# False

# %%
for city in city_iter_1:
    print(city)
# Out:
# CityIterator __iter__ called!
# CityIterator __next__ called
# Paris
# CityIterator __next__ called
# Berlin
# CityIterator __next__ called
# Rome
# CityIterator __next__ called
# Marid
# CityIterator __next__ called
# London
# CityIterator __next__ called

# %%
for city in city_iter_1:
    print(city)
# Out:
# CityIterator __iter__ called!
# CityIterator __next__ called

# %%
del CityIterator
del Cities

# %%
class Cities:
    def __init__(self):
        self._cities = ['Paris', 'Berlin', 'Rome', 'Marid', 'London']
        self._index = 0

    def __len__(self):
        return len(self._cities)
    
    def __iter__(self):
        print("Cities __iter__ called")
        return self.CityIterator(self)
    
    class CityIterator:
        def __init__(self, city_obj: Cities):
            print("CityIterator new object")
            self._city_obj = city_obj
            self._index = 0
        
        def __iter__(self):
            print('CityIterator __iter__ called!')
            return self
        
        def __next__(self):
            print("CityIterator __next__ called")
            if self._index >= len(self._city_obj):
                raise StopIteration
            else:
                item = self._city_obj._cities[self._index]
                self._index += 1
                return item

# %%
cities = Cities()

# %%
for city in cities:
    print(city)
# Out:
# Cities __iter__ called
# CityIterator new object
# CityIterator __next__ called
# Paris
# CityIterator __next__ called
# Berlin
# CityIterator __next__ called
# Rome
# CityIterator __next__ called
# Marid
# CityIterator __next__ called
# London
# CityIterator __next__ called

# %%
list(enumerate(cities))
# Out:
# Cities __iter__ called
# CityIterator new object
# CityIterator __next__ called
# CityIterator __next__ called
# CityIterator __next__ called
# CityIterator __next__ called
# CityIterator __next__ called
# CityIterator __next__ called
# [(0, 'Paris'), (1, 'Berlin'), (2, 'Rome'), (3, 'Marid'), (4, 'London')]

# %%
sorted(cities, key=lambda x: len(x))
# Out:
# Cities __iter__ called
# CityIterator new object
# CityIterator __next__ called
# CityIterator __next__ called
# CityIterator __next__ called
# CityIterator __next__ called
# CityIterator __next__ called
# CityIterator __next__ called
# ['Rome', 'Paris', 'Marid', 'Berlin', 'London']

# %%
city_iterator = cities.__iter__()
# Out:
# Cities __iter__ called
# CityIterator new object

# %%
for city in city_iterator:
    print(city)
# Out:
# CityIterator __iter__ called!
# CityIterator __next__ called
# Paris
# CityIterator __next__ called
# Berlin
# CityIterator __next__ called
# Rome
# CityIterator __next__ called
# Marid
# CityIterator __next__ called
# London
# CityIterator __next__ called

# %%
for city in city_iterator:
    print(city)
# Out:
# CityIterator __iter__ called!
# CityIterator __next__ called

# %%
s = {'a', 100, 'x', 'X'}

# %%
s.__iter__()

# %%
iter(cities)
# Out:
# Cities __iter__ called
# CityIterator new object

# %%
iter(s)

# %%
set_iterator = iter(s)

# %%
for item in set_iterator:
    print(item)
# Out:
# X
# x
# 100
# a

# %%
class Cities:
    def __init__(self):
        self._cities = ['Paris', 'Berlin', 'Rome', 'Marid', 'London']
        self._index = 0

    def __len__(self):
        return len(self._cities)
    
    # def __iter__(self):
    #     print("Cities __iter__ called")
    #     return self.CityIterator(self)
    
    def __getitem__(self, s):
        print('getting item...')
        return self._cities[s]
    
    class CityIterator:
        def __init__(self, city_obj: Cities):
            print("CityIterator new object")
            self._city_obj = city_obj
            self._index = 0
        
        def __iter__(self):
            print('CityIterator __iter__ called!')
            return self
        
        def __next__(self):
            print("CityIterator __next__ called")
            if self._index >= len(self._city_obj):
                raise StopIteration
            else:
                item = self._city_obj._cities[self._index]
                self._index += 1
                return item

# %%
cities = Cities()

# %%
cities[0]
# Out:
# getting item...
# 'Paris'

# %%
for city in cities:
    print(city)
# Out:
# getting item...
# Paris
# getting item...
# Berlin
# getting item...
# Rome
# getting item...
# Marid
# getting item...
# London
# getting item...

# %%
l = [1, 2 ,3, 4]

# %%
iter(k)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 iter(k)
#
# NameError: name 'k' is not defined

# %%
iter(l)

# %%
l.__iter__()

# %%
l.__getitem__
# Out:
# <function list.__getitem__(index, /)>

# %%
l_iter = iter(l)

# %%
l_iter

# %%
for i in l_iter:
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
for i in l_iter:
    print(i)

# %%
next(l_iter)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 next(l_iter)
#
# StopIteration:

# %%
s = {1, 2, 3}

# %%
iter(s)

# %%
s_iter = iter(s)

# %%
next(s_iter)
next(s_iter)
next(s_iter)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[76], line 3
#       1 next(s_iter)
#       2 next(s_iter)
# ----> 3 next(s_iter)
#
# StopIteration:

# %%
s.__getitem__(0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 s.__getitem__(0)
#
# AttributeError: 'set' object has no attribute '__getitem__'
