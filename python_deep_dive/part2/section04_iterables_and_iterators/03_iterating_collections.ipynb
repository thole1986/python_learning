# %%
s = {'x', 'y', 'b', 'c', 'a'}

# %%
for item in s:
    print(item)
# Out:
# c
# a
# x
# y
# b

# %%
s[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 s[0]
#
# TypeError: 'set' object is not subscriptable

# %%
class Squares:
    def __init__(self):
        self.i = 0

    def next_(self):
        result = self.i ** 2
        self.i += 1
        return result

# %%
sq = Squares()

# %%
sq.next_()
# Out:
# 0

# %%
sq.next_()
# Out:
# 1

# %%
sq.next_()
# Out:
# 4

# %%
sq.next_()
# Out:
# 9

# %%
sq = Squares()

# %%
sq.next_()
# Out:
# 0

# %%
sq.next_()
# Out:
# 1

# %%
sq = Squares()

# %%
for i in range(5):
    print(sq.next_())
# Out:
# 0
# 1
# 4
# 9
# 16

# %%
class Squares:
    def __init__(self, length):
        self.length = length
        self.i = 0

    def __len__(self):
        return self.length

    def next_(self):
        if self.i >= self.length:
            raise StopIteration
        else:
            result = self.i ** 2
            self.i += 1
            return result

# %%
sq = Squares(3)

# %%
len(sq)
# Out:
# 3

# %%
sq.next_()
# Out:
# 0

# %%
sq.next_()
# Out:
# 1

# %%
sq.next_()
# Out:
# 4

# %%
sq.next_()
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 sq.next_()
#
# Cell In[16], line 11, in Squares.next_(self)
#       9 def next_(self):
#      10     if self.i >= self.length:
# ---> 11         raise StopIteration
#      12     else:
#      13         result = self.i ** 2
#
# StopIteration:

# %%
sq = Squares(3)

# %%
sq = Squares(10)
while True:
    try:
        print(sq.next_())
    except StopIteration:
        break
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81

# %%
sq.next_()
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 sq.next_()
#
# Cell In[16], line 11, in Squares.next_(self)
#       9 def next_(self):
#      10     if self.i >= self.length:
# ---> 11         raise StopIteration
#      12     else:
#      13         result = self.i ** 2
#
# StopIteration:

# %%
sq = Squares(10)
while True:
    try:
        print(sq.next_())
    except StopIteration:
        break
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81

# %%
class Squares:
    def __init__(self, length):
        self.length = length
        self.i = 0

    def __len__(self):
        return self.length

    def __next__(self):
        if self.i >= self.length:
            raise StopIteration
        else:
            result = self.i ** 2
            self.i += 1
            return result

# %%
sq = Squares(3)

# %%
next(sq)
# Out:
# 0

# %%
next(sq)
# Out:
# 1

# %%
next(sq)
# Out:
# 4

# %%
sq.__next__()
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 sq.__next__()
#
# Cell In[28], line 11, in Squares.__next__(self)
#       9 def __next__(self):
#      10     if self.i >= self.length:
# ---> 11         raise StopIteration
#      12     else:
#      13         result = self.i ** 2
#
# StopIteration:

# %%
sq = Squares(10)
while True:
    try:
        print(next(sq))
    except StopIteration:
        break
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81

# %%
while True:
    try:
        print(next(sq))
    except StopIteration:
        break

# %%
sq = Squares(10)
for item in sq:
    print(sq)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 sq = Squares(10)
# ----> 2 for item in sq:
#       3     print(sq)
#
# TypeError: 'Squares' object is not iterable

# %%
import random

# %%
class RandomNumbers:
    def __init__(self, length, *, range_min=0, range_max=10):
        self.length = length
        self.range_min = range_min
        self.range_max = range_max
        self.num_requested = 0
    
    def __len__(self):
        return self.length
    
    def __next__(self):
        if self.num_requested >= self.length:
            raise StopIteration
        else:
            self.num_requested += 1
            return random.randint(self.range_min, self.range_max)

# %%
numbers = RandomNumbers(3)
next(numbers)
# Out:
# 3

# %%
next(numbers)
# Out:
# 7

# %%
next(numbers)
# Out:
# 9

# %%
next(numbers)
# Out:
# 3

# %%
next(numbers)
# Out:
# 9

# %%
next(numbers)
# Out:
# 1

# %%
next(numbers)
# Out:
# 5

# %%
numbers = RandomNumbers(3)

# %%
print(next(numbers))
print(next(numbers))
print(next(numbers))
# Out:
# 2
# 0
# 3

# %%
next(numbers)
# Out:
# 9

# %%
next(numbers)
# Out:
# 9

# %%
next(numbers)
# Out:
# 5

# %%
next(numbers)
# Out:
# 4

# %%
next(numbers)
# Out:
# 10

# %%
next(numbers)
# Out:
# 7

# %%
next(numbers)
# Out:
# 3

# %%
next(numbers)
# Out:
# 10

# %%
next(numbers)
# Out:
# 5

# %%
next(numbers)
# Out:
# 8

# %%
next(numbers)
# Out:
# 7

# %%
next(numbers)
# Out:
# 3

# %%
numbers = RandomNumbers(10)
while True:
    try:
        print(next(numbers))
    except StopIteration:
        break
# Out:
# 9
# 7
# 4
# 3
# 2
# 4
# 8
# 7
# 0
# 1

# %%
numbers = RandomNumbers(10)

for number in numbers:
    print(numbers)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 3
#       1 numbers = RandomNumbers(10)
# ----> 3 for number in numbers:
#       4     print(numbers)
#
# TypeError: 'RandomNumbers' object is not iterable
