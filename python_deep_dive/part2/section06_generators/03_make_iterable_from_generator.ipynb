# %%
def squares_gen(n):
    for i in range(n):
        yield i ** 2

# %%
sq = squares_gen(5)

# %%
sq
# Out:
# <generator object squares_gen at 0x000002A40542A810>

# %%
for num in sq:
    print(num)
# Out:
# 0
# 1
# 4
# 9
# 16

# %%
list(sq)
# Out:
# []

# %%
class Squares:
    def __init__(self, n):
        self.n = n
    
    def __iter__(self):
        return squares_gen(self.n)

# %%
sq = Squares(5)

# %%
for num in sq:
    print(num)
# Out:
# 0
# 1
# 4
# 9
# 16

# %%
list(sq)
# Out:
# [0, 1, 4, 9, 16]

# %%
list(sq)
# Out:
# [0, 1, 4, 9, 16]

# %%
class Squares:
    def __init__(self, n):
        self.n = n
    
    def __iter__(self):
        return Squares.squares_gen(self.n)

    @staticmethod
    def squares_gen(n):
        for i in range(n):
            yield i ** 2

# %%
sq = Squares(5)
list(sq)
# Out:
# [0, 1, 4, 9, 16]

# %%
def squares(n):
    for i in range(n):
        yield i ** 2

# %%
sq = squares(5)

# %%
enum_sq = enumerate(sq)

# %%
list(enum_sq)
# Out:
# [(0, 0), (1, 1), (2, 4), (3, 9), (4, 16)]

# %%
l = [1, 2, 3]

# %%
enum = enumerate(l)

# %%
list(enum)
# Out:
# [(0, 1), (1, 2), (2, 3)]

# %%
list(enum)
# Out:
# []

# %%
sq = squares(5)

# %%
next(sq)
# Out:
# 0

# %%
next(sq)
# Out:
# 1

# %%
list(enumerate(sq))
# Out:
# [(0, 4), (1, 9), (2, 16)]
