# %%
def fib_recursive(n):
    if n <= 1:
        return 1
    return fib_recursive(n-1) + fib_recursive(n-2)

# %%
[fib_recursive(i) for i in range(7)]
# Out:
# [1, 1, 2, 3, 5, 8, 13]

# %%
from timeit import timeit

# %%
timeit('fib_recursive(10)', globals=globals(),  number=10)
# Out:
# 5.879998207092285e-05

# %%
timeit('fib_recursive(28)', globals=globals(),  number=10)
# Out:
# 0.39139229990541935

# %%
timeit('fib_recursive(29)', globals=globals(),  number=10)
# Out:
# 0.6342731999466196

# %%
from functools import lru_cache

# %%
@lru_cache()
def fib_recursive(n):
    if n <= 1:
        return 1
    else:
        return fib_recursive(n-1) + fib_recursive(n-2)

# %%
timeit('fib_recursive(10)', globals=globals(),  number=10)
# Out:
# 1.1399970389902592e-05

# %%
timeit('fib_recursive(10)', globals=globals(),  number=10)
# Out:
# 3.200024366378784e-06

# %%
timeit('fib_recursive(10)', globals=globals(),  number=10)
# Out:
# 2.9999064281582832e-06

# %%
fib_recursive(2_000)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 fib_recursive(2_000)
#
# Cell In[12], line 6, in fib_recursive(n)
#       4     return 1
#       5 else:
# ----> 6     return fib_recursive(n-1) + fib_recursive(n-2)
#
# Cell In[12], line 6, in fib_recursive(n)
#       4     return 1
#       5 else:
# ----> 6     return fib_recursive(n-1) + fib_recursive(n-2)
#
#     [... skipping similar frames: fib_recursive at line 6 (991 times)]
#
# Cell In[12], line 6, in fib_recursive(n)
#       4     return 1
#       5 else:
# ----> 6     return fib_recursive(n-1) + fib_recursive(n-2)
#
# RecursionError: maximum recursion depth exceeded

# %%
def fib(n):
    fib_0 = 1
    fib_1 = 1
    for i in range(n-1):
        fib_0, fib_1 = fib_1, fib_0 + fib_1
    
    return fib_1

# %%
[fib(i) for i in range(7)]
# Out:
# [1, 1, 2, 3, 5, 8, 13]

# %%
timeit('fib(5000)', globals=globals(),  number=10)
# Out:
# 0.0032917000353336334

# %%
class FibIter:
    def __init__(self, n):
        self.n = n
        self.i = 0

    def __iter__(self):
        return self
    
    def __next__(self):
        if self.i >= self.n:
            raise StopIteration
        else:
            result = fib(self.i)
            self.i += 1
            return result

# %%
fib_iter = FibIter(7)

for num in fib_iter:
    print(num)
# Out:
# 1
# 1
# 2
# 3
# 5
# 8
# 13

# %%
def fib(n):
    fib_0 = 1
    fib_1 = 1
    for i in range(n-1):
        fib_0, fib_1 = fib_1, fib_0 + fib_1
        yield fib_1

# %%
gen = fib(7)

# %%
for num in gen:
    print(num)
# Out:
# 2
# 3
# 5
# 8
# 13
# 21

# %%
def fib(n):
    fib_0 = 1
    yield fib_0
    fib_1 = 1
    yield fib_1
    for i in range(n-1):
        fib_0, fib_1 = fib_1, fib_0 + fib_1
        yield fib_1

# %%
gen = fib(7)

# %%
for num in gen:
    print(num)
# Out:
# 1
# 1
# 2
# 3
# 5
# 8
# 13
# 21

# %%
def fib(n):
    fib_0 = 1
    yield fib_0
    fib_1 = 1
    yield fib_1
    for i in range(n-2):
        fib_0, fib_1 = fib_1, fib_0 + fib_1
        yield fib_1

# %%
gen = fib(7)
for num in gen:
    print(num)
# Out:
# 1
# 1
# 2
# 3
# 5
# 8
# 13

# %%
def fib_standard(n):
    fib_0 = 1
    fib_1 = 1
    for i in range(n-1):
        fib_0, fib_1 = fib_1, fib_0 + fib_1
    
    return fib_1

# %%
def fib_gen(n):
    fib_0 = 1
    yield fib_0
    fib_1 = 1
    yield fib_1
    for i in range(n-2):
        fib_0, fib_1 = fib_1, fib_0 + fib_1
        yield fib_1

# %%
class FibIter:
    def __init__(self, n):
        self.n = n
        self.i = 0

    def __iter__(self):
        return self
    
    def __next__(self):
        if self.i >= self.n:
            raise StopIteration
        else:
            result = fib_standard(self.i)
            self.i += 1
            return result

# %%
timeit('list(FibIter(5000))', globals=globals(), number=1)
# Out:
# 0.7436249000020325

# %%
timeit('list(fib_gen(5000))', globals=globals(), number=1)
# Out:
# 0.000927999964915216
