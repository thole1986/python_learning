# %%
class Person:
    pass

# %%
p = Person()

# %%
bool(p)

# %%
class MyList:
    def __init__(self, length):
        self._length = length
    
    def __len__(self):
        print('__len__ called...')
        return self._length

# %%
l1 = MyList(0)
l2 = MyList(10)

# %%
bool(l1)
