# %%
from functools import wraps

# %%
def debugger(fn):
    @wraps(fn)
    def inner(*args, **kwargs):
        print(f"{fn.__qualname__}", args, kwargs)
        return fn(*args, **kwargs)
    return inner

# %%
@debugger
def func_1(*args, **kwargs):
    pass

@debugger
def func_2(*args, **kwargs):
    pass

# %%
func_1((10, 20), kw='a')
# Out:
# func_1 ((10, 20),) {'kw': 'a'}

# %%
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y

# %%
p = Point(10, 20)

# %%
p.x, p.y
# Out:
# (10, 20)

# %%
class IntegerField:
    def __set_name__(self, owner, name):
        self.name = name
    
    def __get__(self, instance, owner):
        print("__get__ called...", owner)
        return instance.__dict__.get(self.name, None)
    
    def __set__(self, instance, value):
        print("__set__ called...", instance)
        if not isinstance(value, int):
            raise TypeError("Must be an integer.")
        instance.__dict__[self.name]  = value

# %%
class Point:
    x = IntegerField()
    y = IntegerField()

    def __init__(self, x, y):
        self.x = x
        self.y = y

# %%
p = Point(10, 20)
# Out:
# __set__ called... <__main__.Point object at 0x000001C3EB020E00>
# __set__ called... <__main__.Point object at 0x000001C3EB020E00>

# %%
p.x, p.y
# Out:
# __get__ called... <class '__main__.Point'>
# __get__ called... <class '__main__.Point'>
# (10, 20)

# %%
p.x = 10.5
# Out:
# __set__ called... <__main__.Point object at 0x000001C3EB020E00>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 p.x = 10.5
#
# Cell In[16], line 12, in IntegerField.__set__(self, instance, value)
#      10 print("__set__ called...", instance)
#      11 if not isinstance(value, int):
# ---> 12     raise TypeError("Must be an integer.")
#      13 instance.__dict__[self.name]  = value
#
# TypeError: Must be an integer.
