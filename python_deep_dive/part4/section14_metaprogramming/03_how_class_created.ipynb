# %%
import math

class Circle(object):

    def __init__(self, x, y, r):
        self.x = x
        self.y = y
        self.z = r

    def area(self):
        return math.pi * self.r ** 2

# %%
'Circle' in globals()
# Out:
# True

# %%
type(Circle)
# Out:
# type

# %%
Circle
# Out:
# __main__.Circle

# %%
namespace = {}

exec('''
a = 10
b = 20
def __init__(self):
    pass
''', globals(), namespace)

# %%
namespace
# Out:
# {'a': 10, 'b': 20, '__init__': <function __main__.__init__(self)>}

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'import math\n\nclass Circle(object):\n\n    def __init__(self, x, y, r):\n        self.x = x\n        self.y = y\n        self.z = r\n\n    def area(self):\n        return math.pi * self.r ** 2',
#   "'Circle' in globals()",
#   'type(Circle)',
#   'Circle',
#   "namespace = {}\n\nexec('''\n    a = 10\n    b = 20\n\n''', globals(), namespace)",
#   "namespace = {}\n\nexec('''\na = 10\nb = 20\n''', globals(), namespace)",
#   'namespace',
#   "namespace = {}\n\nexec('''\na = 10\nb = 20\ndef __init__(self):\n    pass\n''', globals(), namespace)",
#   'namespace',
#   'globals()'],
#  '_oh': {2: True,
#   3: type,
#   4: __main__.Circle,
#   7: {'a': 10, 'b': 20},
#   9: {'a': 10, 'b': 20, '__init__': <function __main__.__init__(self)>}},
#  '_dh': [WindowsPath('d:/my_coding/python_learning/python_deep_dive/part4/section14_metaprogramming')],
#  'In': ['',
#   'import math\n\nclass Circle(object):\n\n    def __init__(self, x, y, r):\n        self.x = x\n        self.y = y\n        self.z = r\n\n    def area(self):\n        return math.pi * self.r ** 2',
#   "'Circle' in globals()",
#   'type(Circle)',
#   'Circle',
#   "namespace = {}\n\nexec('''\n    a = 10\n    b = 20\n\n''', globals(), namespace)",
#   "namespace = {}\n\nexec('''\na = 10\nb = 20\n''', globals(), namespace)",
#   'namespace',
#   "namespace = {}\n\nexec('''\na = 10\nb = 20\ndef __init__(self):\n    pass\n''', globals(), namespace)",
#   'namespace',
#   'globals()'],
#  'Out': {2: True,
#   3: type,
#   4: __main__.Circle,
#   7: {'a': 10, 'b': 20},
#   9: {'a': 10, 'b': 20, '__init__': <function __main__.__init__(self)>}},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001B6BE56A4B0>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x1b6bfd04350>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x1b6bfd04350>,
#  'open': <function _io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#  '_': {'a': 10, 'b': 20, '__init__': <function __main__.__init__(self)>},
#  '__': {'a': 10, 'b': 20},
#  '___': __main__.Circle,
#  '__vsc_ipynb_file__': 'd:\\my_coding\\python_learning\\python_deep_dive\\part4\\section14_metaprogramming\\03_how_class_created.ipynb',
#  '_i': 'namespace',
#  '_ii': "namespace = {}\n\nexec('''\na = 10\nb = 20\ndef __init__(self):\n    pass\n''', globals(), namespace)",
#  '_iii': 'namespace',
#  '_i1': 'import math\n\nclass Circle(object):\n\n    def __init__(self, x, y, r):\n        self.x = x\n        self.y = y\n        self.z = r\n\n    def area(self):\n        return math.pi * self.r ** 2',
#  'math': <module 'math' (built-in)>,
#  'Circle': __main__.Circle,
#  '_i2': "'Circle' in globals()",
#  '_2': True,
#  '_i3': 'type(Circle)',
#  '_3': type,
#  '_i4': 'Circle',
#  '_4': __main__.Circle,
#  '_i5': "namespace = {}\n\nexec('''\n    a = 10\n    b = 20\n\n''', globals(), namespace)",
#  'namespace': {'a': 10,
#   'b': 20,
#   '__init__': <function __main__.__init__(self)>},
#  '_i6': "namespace = {}\n\nexec('''\na = 10\nb = 20\n''', globals(), namespace)",
#  '_i7': 'namespace',
#  '_7': {'a': 10, 'b': 20},
#  '_i8': "namespace = {}\n\nexec('''\na = 10\nb = 20\ndef __init__(self):\n    pass\n''', globals(), namespace)",
#  '_i9': 'namespace',
#  '_9': {'a': 10, 'b': 20, '__init__': <function __main__.__init__(self)>},
#  '_i10': 'globals()'}

# %%
a = 10
b = 20

def __init__(self):
    pass

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'import math\n\nclass Circle(object):\n\n    def __init__(self, x, y, r):\n        self.x = x\n        self.y = y\n        self.z = r\n\n    def area(self):\n        return math.pi * self.r ** 2',
#   "'Circle' in globals()",
#   'type(Circle)',
#   'Circle',
#   "namespace = {}\n\nexec('''\n    a = 10\n    b = 20\n\n''', globals(), namespace)",
#   "namespace = {}\n\nexec('''\na = 10\nb = 20\n''', globals(), namespace)",
#   'namespace',
#   "namespace = {}\n\nexec('''\na = 10\nb = 20\ndef __init__(self):\n    pass\n''', globals(), namespace)",
#   'namespace',
#   'globals()',
#   'a = 10\nb = 20\n\ndef __init__(self):\n    pass',
#   'globals()'],
#  '_oh': {2: True,
#   3: type,
#   4: __main__.Circle,
#   7: {'a': 10, 'b': 20},
#   9: {'a': 10, 'b': 20, '__init__': <function __main__.__init__(self)>},
#   10: {...}},
#  '_dh': [WindowsPath('d:/my_coding/python_learning/python_deep_dive/part4/section14_metaprogramming')],
#  'In': ['',
#   'import math\n\nclass Circle(object):\n\n    def __init__(self, x, y, r):\n        self.x = x\n        self.y = y\n        self.z = r\n\n    def area(self):\n        return math.pi * self.r ** 2',
#   "'Circle' in globals()",
#   'type(Circle)',
#   'Circle',
#   "namespace = {}\n\nexec('''\n    a = 10\n    b = 20\n\n''', globals(), namespace)",
#   "namespace = {}\n\nexec('''\na = 10\nb = 20\n''', globals(), namespace)",
#   'namespace',
#   "namespace = {}\n\nexec('''\na = 10\nb = 20\ndef __init__(self):\n    pass\n''', globals(), namespace)",
#   'namespace',
#   'globals()',
#   'a = 10\nb = 20\n\ndef __init__(self):\n    pass',
#   'globals()'],
#  'Out': {2: True,
#   3: type,
#   4: __main__.Circle,
#   7: {'a': 10, 'b': 20},
#   9: {'a': 10, 'b': 20, '__init__': <function __main__.__init__(self)>},
#   10: {...}},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000001B6BE56A4B0>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x1b6bfd04350>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x1b6bfd04350>,
#  'open': <function _io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>,
#  '_': {...},
#  '__': {'a': 10, 'b': 20, '__init__': <function __main__.__init__(self)>},
#  '___': {'a': 10, 'b': 20},
#  '__vsc_ipynb_file__': 'd:\\my_coding\\python_learning\\python_deep_dive\\part4\\section14_metaprogramming\\03_how_class_created.ipynb',
#  '_i': 'a = 10\nb = 20\n\ndef __init__(self):\n    pass',
#  '_ii': 'globals()',
#  '_iii': 'namespace',
#  '_i1': 'import math\n\nclass Circle(object):\n\n    def __init__(self, x, y, r):\n        self.x = x\n        self.y = y\n        self.z = r\n\n    def area(self):\n        return math.pi * self.r ** 2',
#  'math': <module 'math' (built-in)>,
#  'Circle': __main__.Circle,
#  '_i2': "'Circle' in globals()",
#  '_2': True,
#  '_i3': 'type(Circle)',
#  '_3': type,
#  '_i4': 'Circle',
#  '_4': __main__.Circle,
#  '_i5': "namespace = {}\n\nexec('''\n    a = 10\n    b = 20\n\n''', globals(), namespace)",
#  'namespace': {'a': 10,
#   'b': 20,
#   '__init__': <function __main__.__init__(self)>},
#  '_i6': "namespace = {}\n\nexec('''\na = 10\nb = 20\n''', globals(), namespace)",
#  '_i7': 'namespace',
#  '_7': {'a': 10, 'b': 20},
#  '_i8': "namespace = {}\n\nexec('''\na = 10\nb = 20\ndef __init__(self):\n    pass\n''', globals(), namespace)",
#  '_i9': 'namespace',
#  '_9': {'a': 10, 'b': 20, '__init__': <function __main__.__init__(self)>},
#  '_i10': 'globals()',
#  '_10': {...},
#  '_i11': 'a = 10\nb = 20\n\ndef __init__(self):\n    pass',
#  'a': 10,
#  'b': 20,
#  '__init__': <function __main__.__init__(self)>,
#  '_i12': 'globals()'}

# %%
class_name = 'Circle'

# %%
class_body = """
def __init__(self, x, y, r):
        self.x = x
        self.y = y
        self.r = r

def area(self):
    return math.pi * self.r ** 2
"""

# %%
class_bases = ()

# %%
class_dict = {}

# %%
exec(class_body, globals(), class_dict)

# %%
class_dict
# Out:
# {'__init__': <function __main__.__init__(self, x, y, r)>,
#  'area': <function __main__.area(self)>}

# %%
Circle = type(class_name, class_bases, class_dict)

# %%
type(Circle)
# Out:
# type

# %%
Circle.__dict__
# Out:
# mappingproxy({'__init__': <function __main__.__init__(self, x, y, r)>,
#               'area': <function __main__.area(self)>,
#               '__module__': '__main__',
#               '__dict__': <attribute '__dict__' of 'Circle' objects>,
#               '__weakref__': <attribute '__weakref__' of 'Circle' objects>,
#               '__doc__': None})

# %%
Circle.__name__
# Out:
# 'Circle'

# %%
c = Circle(0, 0, 1)

# %%
type(c)
# Out:
# __main__.Circle

# %%
c.__dict__
# Out:
# {'x': 0, 'y': 0, 'r': 1}

# %%
c.area()
# Out:
# 3.141592653589793
